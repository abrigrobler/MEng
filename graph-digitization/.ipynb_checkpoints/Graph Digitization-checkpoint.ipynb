# %% [markdown]
# # Digitizing bar graphs in python

# %%
#Imports and such
import csv
import glob
from PIL import Image
import PIL.ImageOps as ImageOps
import numpy as np
import matplotlib.pyplot as plt

# %%
#Open and display example image in greyscale
img = Image.open('example.png').convert('L')
display(img)
# Out:
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9D5BDC0>

# %%
#Convert to array of pixel values
pix = np.array(img.getdata()).reshape(img.size[1], img.size[0])
print(pix)
# Out:
# [[255 217 255 ... 255 255 255]
#  [255 179 255 ... 255 255 255]
#  [255 179 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
#Just so we can make sure our image is still what it used to be
display(Image.fromarray(pix.astype('uint8'), 'L'))
# Out:
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC8EBD1C0>

# %%
#Crop image to get rid of stuff we don't need
cropped_pix = np.delete(pix, np.s_[0:2], axis=1)
cropped_pix = np.delete(cropped_pix, np.s_[cropped_pix.shape[0] - 18:cropped_pix.shape[0]], axis=0)

#Display to check crop
display(Image.fromarray(cropped_pix.astype('uint8')+255, 'L'))

#Invert the image
cropped_pix = 255-cropped_pix
# Out:
# <PIL.Image.Image image mode=L size=708x64 at 0x7F7FC9D5B4F0>

# %%
#Extract vertical "bars" from image pixel array
bars = []
average_bars = []
for i in range(24):
    bars.append(cropped_pix[:,int((i*cropped_pix.shape[1])/24)+10])

#Calculate average pixel value from each bar, as this will correspond to the average height of that bar
for bar in bars:
    average_bars.append(np.mean(bar))

#Normalise
average_bars = average_bars/np.max(average_bars)

#Plot to check data
plt.figure(figsize=(12, 2))
plt.bar(range(0,24), average_bars)
plt.show()

#Maybe convert this to a histogram

# %% [markdown]
# ### Let's test this as a function

# %%
def image_to_graph(image_path, crop_left, crop_bottom, bar_offset):
    
    img = Image.open(image_path).convert('L')
    pix = np.array(img.getdata()).reshape(img.size[1], img.size[0])
    print("Greyscale image")
    display(Image.fromarray(pix.astype('uint8'), 'L'))
    
    #Crop image to get rid of stuff we don't need
    cropped_pix = np.delete(pix, np.s_[0:crop_left], axis=1)
    cropped_pix = np.delete(cropped_pix, np.s_[cropped_pix.shape[0] - crop_bottom:cropped_pix.shape[0]], axis=0)

    #Display to check crop
    print("Cropped image")
    display(Image.fromarray(cropped_pix.astype('uint8')+255, 'L'))

    #Invert the image
    cropped_pix = 255-cropped_pix
    
    #Extract vertical "bars" from image pixel array
    bars = []
    average_bars = []
    for i in range(24):
        bars.append(cropped_pix[:,int((i*cropped_pix.shape[1])/24)+bar_offset])

    #Calculate average pixel value from each bar, as this will correspond to the average height of that bar
    for bar in bars:
        average_bars.append(np.mean(bar))
    
    average_bars = average_bars/np.max(average_bars)
    
    #Plot to check data
    print("Extracted data")
    plt.figure(figsize=(12, 2))
    plt.bar(range(0,24), average_bars)
    plt.show()
    print("\n\n")
    
    return average_bars

# All files and directories ending with .txt and that don't begin with a dot:
files = glob.glob("./charts/*.png")

# open the file in the write mode
f = open('data.csv', 'w')

# create the csv writer
writer = csv.writer(f)

for i in range(len(files)):
    print("Graph nr", str(i+1))
    writer.writerow(image_to_graph(files[i], 2, 20, 10))

f.close()
# Out:
# Graph nr 1
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8201E20>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F05E50>
# Extracted data
# Graph nr 2
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F0C9A0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA84E9730>
# Extracted data
# Graph nr 3
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8665BE0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8665E50>
# Extracted data
# Graph nr 4
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9D90940>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA866C250>
# Extracted data
# Graph nr 5
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB880CFA0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB881AEB0>
# Extracted data
# Graph nr 6
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA86B6310>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA86BDFD0>
# Extracted data
# Graph nr 7
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA86B67C0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB881A160>
# Extracted data
# Graph nr 8
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA0B18E0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA0B1C70>
# Extracted data
# Graph nr 9
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA0D1DC0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA0BF340>
# Extracted data
# Graph nr 10
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA0B9D30>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA0BF9A0>
# Extracted data
# Graph nr 11
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA242D00>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA242250>
# Extracted data
# Graph nr 12
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA0B17C0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F983D4D00>
# Extracted data
# Graph nr 13
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9D87FD0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA0B12B0>
# Extracted data
# Graph nr 14
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F983EBF10>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA88D6580>
# Extracted data
# Graph nr 15
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA86755E0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA85D6DC0>
# Extracted data
# Graph nr 16
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F98405040>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB881EA00>
# Extracted data
# Graph nr 17
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F18F10>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F18BB0>
# Extracted data
# Graph nr 18
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA872C2E0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA15BA90>
# Extracted data
# Graph nr 19
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA872C850>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA86A5A90>
# Extracted data
# Graph nr 20
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F9C550>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F9C0D0>
# Extracted data
# Graph nr 21
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA87C7C70>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB8867E20>
# Extracted data
# Graph nr 22
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA86F0CA0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA86F02E0>
# Extracted data
# Graph nr 23
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA86F0340>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA87B79A0>
# Extracted data
# Graph nr 24
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F666D0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F983C7700>
# Extracted data
# Graph nr 25
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA85A6100>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA85A6D30>
# Extracted data
# Graph nr 26
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9FA5FA0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA85A6550>
# Extracted data
# Graph nr 27
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8796D00>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8789C70>
# Extracted data
# Graph nr 28
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA85ADA90>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8730DF0>
# Extracted data
# Graph nr 29
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB87E3F10>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9FA7100>
# Extracted data
# Graph nr 30
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA87A8190>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB87E4580>
# Extracted data
# Graph nr 31
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F983E5580>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F983E5BE0>
# Extracted data
# Graph nr 32
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA24FD30>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA88FC370>
# Extracted data
# Graph nr 33
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA170AC0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA25EC70>
# Extracted data
# Graph nr 34
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC95F01C0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB88014C0>
# Extracted data
# Graph nr 35
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9E57AC0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA170BB0>
# Extracted data
# Graph nr 36
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB87D0220>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB87E3E20>
# Extracted data
# Graph nr 37
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB87CFF10>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA87B75E0>
# Extracted data
# Graph nr 38
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F3FD90>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA17DBE0>
# Extracted data
# Graph nr 39
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA84E6490>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA87B7220>
# Extracted data
# Graph nr 40
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA0D3FA0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8731220>
# Extracted data
# Graph nr 41
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F73730>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA88DDAF0>
# Extracted data
# Graph nr 42
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F9EFD0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8776880>
# Extracted data
# Graph nr 43
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F7D790>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F7D280>
# Extracted data
# Graph nr 44
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA868CD30>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB89B5A90>
# Extracted data
# Graph nr 45
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC8E30E20>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA868CE80>
# Extracted data
# Graph nr 46
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA85AD400>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA0A7250>
# Extracted data
# Graph nr 47
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA87A8A90>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA87A8760>
# Extracted data
# Graph nr 48
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA0B15E0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F9803FDF0>
# Extracted data
# Graph nr 49
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F9803B670>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9D81D30>
# Extracted data
# Graph nr 50
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F9803BD90>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8671EE0>
# Extracted data
# Graph nr 51
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB8815940>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB8848FD0>
# Extracted data
# Graph nr 52
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA890CF10>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F983E4310>
# Extracted data
# Graph nr 53
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA1E8340>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA1D3B20>
# Extracted data
# Graph nr 54
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9E549D0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA1F5CA0>
# Extracted data
# Graph nr 55
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA248670>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA2486A0>
# Extracted data
# Graph nr 56
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA88DD5E0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA24F2E0>
# Extracted data
# Graph nr 57
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA87A8820>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC95F01C0>
# Extracted data
# Graph nr 58
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA0B12E0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA0B16A0>
# Extracted data
# Graph nr 59
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA86FC130>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F980463D0>
# Extracted data
# Graph nr 60
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB8987880>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F7D2E0>
# Extracted data
# Graph nr 61
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9D87BE0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9D87BE0>
# Extracted data
# Graph nr 62
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA23F4F0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F95BE0>
# Extracted data
# Graph nr 63
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F43CD0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA85BB880>
# Extracted data
# Graph nr 64
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8774A60>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F43520>
# Extracted data
# Graph nr 65
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F980363D0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA869A550>
# Extracted data
# Graph nr 66
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA86B6850>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA86B6700>
# Extracted data
# Graph nr 67
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8645E20>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB881E0D0>
# Extracted data
# Graph nr 68
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8675520>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA841FF10>
# Extracted data
# Graph nr 69
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9D81F10>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8730460>
# Extracted data
# Graph nr 70
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9D81BB0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9D907C0>
# Extracted data
# Graph nr 71
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA85C1970>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA85D17C0>
# Extracted data
# Graph nr 72
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F9803FB80>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F9803FB80>
# Extracted data
# Graph nr 73
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8651F40>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F983C78E0>
# Extracted data
# Graph nr 74
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F539D0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA1DD520>
# Extracted data
# Graph nr 75
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9FB5BE0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F53580>
# Extracted data
# Graph nr 76
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA866A760>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA870F790>
# Extracted data
# Graph nr 77
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA874A3A0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9FC09A0>
# Extracted data
# Graph nr 78
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA0AE430>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA84EECA0>
# Extracted data
# Graph nr 79
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC95F01C0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9FC05E0>
# Extracted data
# Graph nr 80
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F983D4DF0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F98394D00>
# Extracted data
# Graph nr 81
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F983BBDF0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA2552B0>
# Extracted data
# Graph nr 82
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F983C77F0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA88F2AF0>
# Extracted data
# Graph nr 83
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB87C96D0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB87C9610>
# Extracted data
# Graph nr 84
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB880D910>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9D872B0>
# Extracted data
# Graph nr 85
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA1CF9A0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB87BB100>
# Extracted data
# Graph nr 86
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9E41AC0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA87755B0>
# Extracted data
# Graph nr 87
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA870ECA0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9E43400>
# Extracted data
# Graph nr 88
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA87888B0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8788370>
# Extracted data
# Graph nr 89
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9EF7490>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9D87DC0>
# Extracted data
# Graph nr 90
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8675790>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8675B80>
# Extracted data
# Graph nr 91
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8730AF0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9D7D8B0>
# Extracted data
# Graph nr 92
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8771F40>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9E41BB0>
# Extracted data
# Graph nr 93
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA86A4220>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9E430D0>
# Extracted data
# Graph nr 94
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA85BF9D0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA1E4D30>
# Extracted data
# Graph nr 95
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA242070>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8771880>
# Extracted data
# Graph nr 96
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8654610>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA85146A0>
# Extracted data
# Graph nr 97
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F86910>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F8AEE0>
# Extracted data
# Graph nr 98
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8654970>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA248FA0>
# Extracted data
# Graph nr 99
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA16A3A0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F971C0>
# Extracted data
# Graph nr 100
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB8868EB0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F860A0>
# Extracted data
# Graph nr 101
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA23C040>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB8868F10>
# Extracted data
# Graph nr 102
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB885BCA0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA85B44C0>
# Extracted data
# Graph nr 103
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA25E250>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA25E250>
# Extracted data
# Graph nr 104
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA88F2E80>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA25E2B0>
# Extracted data
# Graph nr 105
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA87B42E0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA87B4CA0>
# Extracted data
# Graph nr 106
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB87FB5E0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA878B430>
# Extracted data
# Graph nr 107
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9E5DC10>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA87A3280>
# Extracted data
# Graph nr 108
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F1FA90>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F1F970>
# Extracted data
# Graph nr 109
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F29D30>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9E22550>
# Extracted data
# Graph nr 110
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F983F8910>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA88D9640>
# Extracted data
# Graph nr 111
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F9803FE20>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA88F8AC0>
# Extracted data
# Graph nr 112
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB88011F0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F983BB2E0>
# Extracted data
# Graph nr 113
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA85B48E0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F66E50>
# Extracted data
# Graph nr 114
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB87E5C10>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA841FF40>
# Extracted data
# Graph nr 115
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB87CF460>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA87A8CA0>
# Extracted data
# Graph nr 116
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA8771880>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F983D4340>
# Extracted data
# Graph nr 117
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA85B9A00>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA85B9AC0>
# Extracted data
# Graph nr 118
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FA859B8E0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA8655B50>
# Extracted data
# Graph nr 119
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F71DC0>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FC9F71EE0>
# Extracted data
# Graph nr 120
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FC9F71D60>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FB8864820>
# Extracted data
# Graph nr 121
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA15D370>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA15D1F0>
# Extracted data
# Graph nr 122
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7F98394220>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FA866E6D0>
# Extracted data
# Graph nr 123
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FCA1C1370>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7F98394640>
# Extracted data
# Graph nr 124
# Greyscale image
# <PIL.Image.Image image mode=L size=710x82 at 0x7F7FB8874F10>
# Cropped image
# <PIL.Image.Image image mode=L size=708x62 at 0x7F7FCA1C1460>
# Extracted data
